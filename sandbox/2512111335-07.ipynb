# %% [markdown]
# ### 0 Helper function

# %%
import yaml
import json

# %%
class helperfunction():
    def load_file(self,filepath):
        with open(filepath,'r',encoding="utf-8") as f:
            return f.read()
    def load_yaml(self,filepath):
        with open(filepath,'r',encoding="utf-8") as f:
            return yaml.safe_load(f)
    def fop(self,float_num):
        return float(f"{float_num:.1f}")
    def jsonstr(self,ip):
        return str(json.dumps(ip,indent=4, ensure_ascii=False))

# %% [markdown]
# <hr>

# %% [markdown]
# ### 01 Input CVResume

# %%
hp = helperfunction()
resume_json = hp.load_file("resume_json.txt")
print(resume_json)
# Out:
# {
#   "contact_information": {
#     "name": "Surya Teja Menta",
#     "email": "-",
#     "phone": "+91 8309584461",
#     "linkedin": "-",
#     "jobdb_link": "-",
#     "portfolio_link": "suryatejamenta.co.in"
#   },
#   "professional_summary": {
#     "has_summary": "Yes",
#     "summary_points": [
#       "I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).",
#       "Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.",
#       "Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.",
#       "IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).",
#       "Passionate about AI research, model optimization, and developing cutting-edge AI solutions."
#     ]
#   },
#   "education": [
#     {
#       "institution": "PBR VITS, Kavali, AP",
#       "degree": "Bachelor's Degree in Computer Science",
#       "dates": "June 2016 - May 2020",
#       "gpa": "78.3%",
#       "honors": "Participated in paper presentations and won prizes."
#     },
#     {
#       "institution": "Narayana Junior College, Kavali, AP",
#       "degree": "HSC",
#       "dates": "June 2014 - May 2016",
#       "gpa": "92.5%",
#       "honors": "-"
#     },
#     {
#       "institution": "Kranthi EM School, Kavali, AP",
#       "degree": "SSC",
#       "dates": "June 2004 - May 2014",
#       "gpa": "87%",
#       "honors": "Participated in school dramas, sports, etc."
#     }
#   ],
#   "experience": [
#     {
#       "title": "Senior Data Scientist",
#       "company": "Robert Bosch",
#       "dates": "Jan 2024 - Present",
#       "description": [
#         "Designed and deployed custom YOLOv8 models for computer vision applications.",
#         "Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.",
#         "Worked on Time series data for Adnoc Project.",
#         "Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.",
#         "Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.",
#         "Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment."
#       ]
#     },
#     {
#       "title": "Subject Matter Expert (Data Analyst)",
#       "company": "Tudip Technologies",
#       "dates": "Oct 2020 - Oct 2023",
#       "description": [
#         "Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.",
#         "Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.",
#         "Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.",
#         "Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.",
#         "Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation."
#       ]
#     }
#   ],
#   "skills": {
#     "technical": [
#       "Data Science",
#       "Machine Learning",
#       "Deep Learning",
#       "NLP",
#       "Computer Vision",
#       "LLMs",
#       "LLM Fine Tuning",
#       "Generative AI",
#       "OpenCV",
#       "YOLOv8",
#       "Image Processing",
#       "Object Detection",
#       "GANs",
#       "Signal Processing",
#       "Time Series Analysis",
#       "Tensorflow",
#       "Pytorch",
#       "Keras",
#       "Langchain",
#       "GCP Cloud Run",
#       "Amazon SageMaker",
#       "Numpy",
#       "Pandas",
#       "Scikit-learn",
#       "Spacy",
#       "NLTK",
#       "Matplotlib",
#       "Seaborn",
#       "Scipy",
#       "Jupyter Notebooks",
#       "Docker",
#       "GitHub",
#       "Git",
#       "Google Data Studio",
#       "Statistics & Probability",
#       "Calculus",
#       "Mathematics",
#       "Linear Algebra",
#       "Statistical Analysis",
#       "Data Mining",
#       "Model Building",
#       "Model Deployment",
#       "Hypothesis Testing",
#       "Data Analytics"
#     ],
#     "soft_skills": [
#       "Analytical Thinking",
#       "Problem Solving",
#       "Collaboration",
#       "Communication",
#       "Continuous Learning",
#       "Adaptability",
#       "Time Management"
#     ],
#     "tools_with_levels": [
#       {
#         "tool": "Amazon SageMaker",
#         "level": "basic"
#       }
#     ],
#     "languages": [
#       {
#         "language": "Python",
#         "level": "-"
#       },
#       {
#         "language": "SQL",
#         "level": "-"
#       },
#       {
#         "language": "HTML",
#         "level": "-"
#       },
#       {
#         "language": "CSS",
#         "level": "-"
#       }
#     ]
#   }
# }
# ```
# {'contact_information': {'name': 'Surya Teja Menta',
#   'email': '-',
#   'phone': '+91 8309584461',
#   'linkedin': '-',
#   'jobdb_link': '-',
#   'portfolio_link': 'suryatejamenta.co.in'},
#  'professional_summary': {'has_summary': 'Yes',
#   'summary_points': ['I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).',
#    'Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.',
#    'Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.',
#    'IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).',
#    'Passionate about AI research, model optimization, and developing cutting-edge AI solutions.']},
#  'education': [{'institution': 'PBR VITS, Kavali, AP',
#    'degree': "Bachelor's Degree in Computer Science",
#    'dates': 'June 2016 - May 2020',
#    'gpa': '78.3%',
#    'honors': 'Participated in paper presentations and won prizes.'},
#   {'institution': 'Narayana Junior College, Kavali, AP',
#    'degree': 'HSC',
#    'dates': 'June 2014 - May 2016',
#    'gpa': '92.5%',
#    'honors': '-'},
#   {'institution': 'Kranthi EM School, Kavali, AP',
#    'degree': 'SSC',
#    'dates': 'June 2004 - May 2014',
#    'gpa': '87%',
#    'honors': 'Participated in school dramas, sports, etc.'}],
#  'experience': [{'title': 'Senior Data Scientist',
#    'company': 'Robert Bosch',
#    'dates': 'Jan 2024 - Present',
#    'description': ['Designed and deployed custom YOLOv8 models for computer vision applications.',
#     'Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.',
#     'Worked on Time series data for Adnoc Project.',
#     'Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.',
#     'Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.',
#     'Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment.']},
#   {'title': 'Subject Matter Expert (Data Analyst)',
#    'company': 'Tudip Technologies',
#    'dates': 'Oct 2020 - Oct 2023',
#    'description': ['Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.',
#     'Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.',
#     'Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.',
#     'Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.',
#     'Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation.']}],
#  'skills': {'technical': ['Data Science',
#    'Machine Learning',
#    'Deep Learning',
#    'NLP',
#    'Computer Vision',
#    'LLMs',
#    'LLM Fine Tuning',
#    'Generative AI',
#    'OpenCV',
#    'YOLOv8',
#    'Image Processing',
#    'Object Detection',
#    'GANs',
#    'Signal Processing',
#    'Time Series Analysis',
#    'Tensorflow',
#    'Pytorch',
#    'Keras',
#    'Langchain',
#    'GCP Cloud Run',
#    'Amazon SageMaker',
#    'Numpy',
#    'Pandas',
#    'Scikit-learn',
#    'Spacy',
#    'NLTK',
#    'Matplotlib',
#    'Seaborn',
#    'Scipy',
#    'Jupyter Notebooks',
#    'Docker',
#    'GitHub',
#    'Git',
#    'Google Data Studio',
#    'Statistics & Probability',
#    'Calculus',
#    'Mathematics',
#    'Linear Algebra',
#    'Statistical Analysis',
#    'Data Mining',
#    'Model Building',
#    'Model Deployment',
#    'Hypothesis Testing',
#    'Data Analytics'],
#   'soft_skills': ['Analytical Thinking',
#    'Problem Solving',
#    'Collaboration',
#    'Communication',
#    'Continuous Learning',
#    'Adaptability',
#    'Time Management'],
#   'tools_with_levels': [{'tool': 'Amazon SageMaker', 'level': 'basic'}],
#   'languages': [{'language': 'Python', 'level': '-'},
#    {'language': 'SQL', 'level': '-'},
#    {'language': 'HTML', 'level': '-'},
#    {'language': 'CSS', 'level': '-'}]}}

# %% [markdown]
# <hr>

# %% [markdown]
# ### 02 Promptbuilder

# %%
from google import genai
import json
import os
import yaml

# %%
class PromptBuilder(helperfunction):
    def __init__(self,section,criteria,cvresume):
        self.section  = section
        self.criteria = criteria[::-1]
        self.cvresume = cvresume
        self.config = self.load_yaml("prompt.yaml")
        # print(self.config)
    def build_response_template(self):
        return {
            "section": self.section,
            "scores": {
                c: {"score": 0, "feedback": ""} for c in self.criteria
            }
        }
    def build(self):
        config_role      = self.config['role']['role1']
        config_objective = self.config['objective']['objective1']
        config_section   = self.config['section']['section1']
        config_expected  = self.config['expected_content'][self.section]
        config_criteria  = ""
        for item in self.criteria:
            config_criteria = f"- {item}\n" + config_criteria
        config_scale     = self.config['scale']['score1']
        # config_output    = self.config['output']['format1']
        
        prompt_role      = f"Role :\n{config_role}"+"\n\n"
        prompt_objective = f"objectvie :\n{config_objective}"+"\n\n"
        prompt_section   = f"section :\n{config_section}"+"\n\n"
        prompt_expected  = f"expected :\n{config_expected}"+"\n"
        prompt_criteria  = f"Criteria :\n{config_criteria}"+"\n"
        prompt_scale     = f"Scale :\n{config_scale}"+"\n"
        prompt_output    = f"output :\n{json.dumps(self.build_response_template(), indent=2)}"+"\n\n"
        prompt_cvresume  = f"CV/Resume: \n{self.cvresume}"+"\n"

        prompt = prompt_role + prompt_objective + prompt_section \
            + prompt_expected + prompt_criteria + prompt_scale \
            + prompt_output + prompt_cvresume
        prompt = prompt.replace("<section_name>",self.section)
        return prompt

# %%
p1 = PromptBuilder( 
    section  = "Profile", 
    criteria = ["Completeness", "ContentQuality"],
    cvresume = resume_json,
    fewshot = "xxx" # structure fewshot
    role    = "yyy"
)
prompt1 = p1.build()
# print(prompt1)
# Out:
#   Cell In[7], line 5
#     fewshot = "xxx" # structure fewshot
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
p1 = PromptBuilder( 
    section  = "Profile", 
    criteria = ["Completeness", "ContentQuality"],
    cvresume = resume_json
)
prompt1 = p1.build()
print(prompt1)
# Out:
# Role :
# You are the expert HR evaluator
#
# objectvie :
# Evaluate the Profile section from the resume using the scoring criteria.
# Measure how well the candidate matches the <targetrole> role.
# Consider: degree relevance, experience alignment, skills/tools, and seniority evidence.
# Score 0-5 using the scale below.
#
#
# section :
# You are evaluating the Profile section.
#
# expected :
# Content checklist:
# - Candidate's basic professional identity
# - Clear positioning (e.g., "Data Analyst", "ML Engineer")
# - Career direction or headline
# - Avoid unnecessary personal details
#
# Feedback guideline:
# - Feedback should be ~20 words.
# - Focus on how well the profile supports the <targetrole> role.
#
# Few-shot examples (Profile quality):
#
# Score 5 (excellent):
# "Data scientist with 4+ years experience building ML models in Python (pandas, scikit-learn) for customer analytics, now targeting Senior Data Scientist roles."
#
# Score 3 (sufficient):
# "Data analyst with 2 years of experience in reporting and basic SQL, looking to grow into data science roles."
#
# Score 1 (poor):
# "Student interested in data, marketing, and design, looking for any opportunity."
#
# Criteria :
# - Completeness
# - ContentQuality
#
# Scale :
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# output :
# {
#   "section": "Profile",
#   "scores": {
#     "ContentQuality": {
#       "score": 0,
#       "feedback": ""
#     },
#     "Completeness": {
#       "score": 0,
#       "feedback": ""
#     }
#   }
# }
#
# CV/Resume:
# {
#   "contact_information": {
#     "name": "Surya Teja Menta",
#     "email": "-",
#     "phone": "+91 8309584461",
#     "linkedin": "-",
#     "jobdb_link": "-",
#     "portfolio_link": "suryatejamenta.co.in"
#   },
#   "professional_summary": {
#     "has_summary": "Yes",
#     "summary_points": [
#       "I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).",
#       "Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.",
#       "Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.",
#       "IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).",
#       "Passionate about AI research, model optimization, and developing cutting-edge AI solutions."
#     ]
#   },
#   "education": [
#     {
#       "institution": "PBR VITS, Kavali, AP",
#       "degree": "Bachelor's Degree in Computer Science",
#       "dates": "June 2016 - May 2020",
#       "gpa": "78.3%",
#       "honors": "Participated in paper presentations and won prizes."
#     },
#     {
#       "institution": "Narayana Junior College, Kavali, AP",
#       "degree": "HSC",
#       "dates": "June 2014 - May 2016",
#       "gpa": "92.5%",
#       "honors": "-"
#     },
#     {
#       "institution": "Kranthi EM School, Kavali, AP",
#       "degree": "SSC",
#       "dates": "June 2004 - May 2014",
#       "gpa": "87%",
#       "honors": "Participated in school dramas, sports, etc."
#     }
#   ],
#   "experience": [
#     {
#       "title": "Senior Data Scientist",
#       "company": "Robert Bosch",
#       "dates": "Jan 2024 - Present",
#       "description": [
#         "Designed and deployed custom YOLOv8 models for computer vision applications.",
#         "Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.",
#         "Worked on Time series data for Adnoc Project.",
#         "Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.",
#         "Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.",
#         "Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment."
#       ]
#     },
#     {
#       "title": "Subject Matter Expert (Data Analyst)",
#       "company": "Tudip Technologies",
#       "dates": "Oct 2020 - Oct 2023",
#       "description": [
#         "Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.",
#         "Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.",
#         "Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.",
#         "Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.",
#         "Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation."
#       ]
#     }
#   ],
#   "skills": {
#     "technical": [
#       "Data Science",
#       "Machine Learning",
#       "Deep Learning",
#       "NLP",
#       "Computer Vision",
#       "LLMs",
#       "LLM Fine Tuning",
#       "Generative AI",
#       "OpenCV",
#       "YOLOv8",
#       "Image Processing",
#       "Object Detection",
#       "GANs",
#       "Signal Processing",
#       "Time Series Analysis",
#       "Tensorflow",
#       "Pytorch",
#       "Keras",
#       "Langchain",
#       "GCP Cloud Run",
#       "Amazon SageMaker",
#       "Numpy",
#       "Pandas",
#       "Scikit-learn",
#       "Spacy",
#       "NLTK",
#       "Matplotlib",
#       "Seaborn",
#       "Scipy",
#       "Jupyter Notebooks",
#       "Docker",
#       "GitHub",
#       "Git",
#       "Google Data Studio",
#       "Statistics & Probability",
#       "Calculus",
#       "Mathematics",
#       "Linear Algebra",
#       "Statistical Analysis",
#       "Data Mining",
#       "Model Building",
#       "Model Deployment",
#       "Hypothesis Testing",
#       "Data Analytics"
#     ],
#     "soft_skills": [
#       "Analytical Thinking",
#       "Problem Solving",
#       "Collaboration",
#       "Communication",
#       "Continuous Learning",
#       "Adaptability",
#       "Time Management"
#     ],
#     "tools_with_levels": [
#       {
#         "tool": "Amazon SageMaker",
#         "level": "basic"
#       }
#     ],
#     "languages": [
#       {
#         "language": "Python",
#         "level": "-"
#       },
#       {
#         "language": "SQL",
#         "level": "-"
#       },
#       {
#         "language": "HTML",
#         "level": "-"
#       },
#       {
#         "language": "CSS",
#         "level": "-"
#       }
#     ]
#   }
# }
# ```
# {'contact_information': {'name': 'Surya Teja Menta',
#   'email': '-',
#   'phone': '+91 8309584461',
#   'linkedin': '-',
#   'jobdb_link': '-',
#   'portfolio_link': 'suryatejamenta.co.in'},
#  'professional_summary': {'has_summary': 'Yes',
#   'summary_points': ['I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).',
#    'Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.',
#    'Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.',
#    'IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).',
#    'Passionate about AI research, model optimization, and developing cutting-edge AI solutions.']},
#  'education': [{'institution': 'PBR VITS, Kavali, AP',
#    'degree': "Bachelor's Degree in Computer Science",
#    'dates': 'June 2016 - May 2020',
#    'gpa': '78.3%',
#    'honors': 'Participated in paper presentations and won prizes.'},
#   {'institution': 'Narayana Junior College, Kavali, AP',
#    'degree': 'HSC',
#    'dates': 'June 2014 - May 2016',
#    'gpa': '92.5%',
#    'honors': '-'},
#   {'institution': 'Kranthi EM School, Kavali, AP',
#    'degree': 'SSC',
#    'dates': 'June 2004 - May 2014',
#    'gpa': '87%',
#    'honors': 'Participated in school dramas, sports, etc.'}],
#  'experience': [{'title': 'Senior Data Scientist',
#    'company': 'Robert Bosch',
#    'dates': 'Jan 2024 - Present',
#    'description': ['Designed and deployed custom YOLOv8 models for computer vision applications.',
#     'Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.',
#     'Worked on Time series data for Adnoc Project.',
#     'Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.',
#     'Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.',
#     'Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment.']},
#   {'title': 'Subject Matter Expert (Data Analyst)',
#    'company': 'Tudip Technologies',
#    'dates': 'Oct 2020 - Oct 2023',
#    'description': ['Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.',
#     'Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.',
#     'Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.',
#     'Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.',
#     'Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation.']}],
#  'skills': {'technical': ['Data Science',
#    'Machine Learning',
#    'Deep Learning',
#    'NLP',
#    'Computer Vision',
#    'LLMs',
#    'LLM Fine Tuning',
#    'Generative AI',
#    'OpenCV',
#    'YOLOv8',
#    'Image Processing',
#    'Object Detection',
#    'GANs',
#    'Signal Processing',
#    'Time Series Analysis',
#    'Tensorflow',
#    'Pytorch',
#    'Keras',
#    'Langchain',
#    'GCP Cloud Run',
#    'Amazon SageMaker',
#    'Numpy',
#    'Pandas',
#    'Scikit-learn',
#    'Spacy',
#    'NLTK',
#    'Matplotlib',
#    'Seaborn',
#    'Scipy',
#    'Jupyter Notebooks',
#    'Docker',
#    'GitHub',
#    'Git',
#    'Google Data Studio',
#    'Statistics & Probability',
#    'Calculus',
#    'Mathematics',
#    'Linear Algebra',
#    'Statistical Analysis',
#    'Data Mining',
#    'Model Building',
#    'Model Deployment',
#    'Hypothesis Testing',
#    'Data Analytics'],
#   'soft_skills': ['Analytical Thinking',
#    'Problem Solving',
#    'Collaboration',
#    'Communication',
#    'Continuous Learning',
#    'Adaptability',
#    'Time Management'],
#   'tools_with_levels': [{'tool': 'Amazon SageMaker', 'level': 'basic'}],
#   'languages': [{'language': 'Python', 'level': '-'},
#    {'language': 'SQL', 'level': '-'},
#    {'language': 'HTML', 'level': '-'},
#    {'language': 'CSS', 'level': '-'}]}}

# %%
p2 = PromptBuilder( 
    section  = "Summary", 
    criteria = ["Completeness", "ContentQuality","Grammar","Length","RoleRelevance"],
    cvresume = resume_json
)
prompt2 = p2.build()
print(prompt2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 p2 = PromptBuilder(
#       2     section  = "Summary",
#       3     criteria = ["Completeness", "ContentQuality","Grammar","Length","RoleRelevance"],
#       4     cvresume = resume_json
#       5 )
#       6 prompt2 = p2.build()
#       7 print(prompt2)
#
# NameError: name 'PromptBuilder' is not defined

# %%
p3 = PromptBuilder( 
    section  = "Education", 
    criteria = ["Completeness","RoleRelevance"],
    cvresume = resume_json
)
prompt3 = p3.build()
# print(prompt3)

# %%
print(prompt3)
# Out:
# Role :
# You are the expert HR evaluator
#
# objectvie :
# Evaluate the Education section from the resume using the scoring criteria
#
# section :
# You are evaluating the Education section.
#
# expected :
# - Institution name
# - Degree & field of study
# - Dates attended
# - GPA, honors (optional)
# - Relevance to data career
#
# Criteria :
# - Completeness
# - RoleRelevance
#
# Scale :
# 0 = missing
# 1 = poor
# 2 = weak
# 3 = sufficient
# 4 = strong
# 5 = excellent
#
# output :
# {
#   "section": "Education",
#   "scores": {
#     "RoleRelevance": {
#       "score": 0,
#       "feedback": ""
#     },
#     "Completeness": {
#       "score": 0,
#       "feedback": ""
#     }
#   }
# }
#
# CV/Resume:
# {
#   "contact_information": {
#     "name": "Surya Teja Menta",
#     "email": "-",
#     "phone": "+91 8309584461",
#     "linkedin": "-",
#     "jobdb_link": "-",
#     "portfolio_link": "suryatejamenta.co.in"
#   },
#   "professional_summary": {
#     "has_summary": "Yes",
#     "summary_points": [
#       "I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).",
#       "Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.",
#       "Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.",
#       "IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).",
#       "Passionate about AI research, model optimization, and developing cutting-edge AI solutions."
#     ]
#   },
#   "education": [
#     {
#       "institution": "PBR VITS, Kavali, AP",
#       "degree": "Bachelor's Degree in Computer Science",
#       "dates": "June 2016 - May 2020",
#       "gpa": "78.3%",
#       "honors": "Participated in paper presentations and won prizes."
#     },
#     {
#       "institution": "Narayana Junior College, Kavali, AP",
#       "degree": "HSC",
#       "dates": "June 2014 - May 2016",
#       "gpa": "92.5%",
#       "honors": "-"
#     },
#     {
#       "institution": "Kranthi EM School, Kavali, AP",
#       "degree": "SSC",
#       "dates": "June 2004 - May 2014",
#       "gpa": "87%",
#       "honors": "Participated in school dramas, sports, etc."
#     }
#   ],
#   "experience": [
#     {
#       "title": "Senior Data Scientist",
#       "company": "Robert Bosch",
#       "dates": "Jan 2024 - Present",
#       "description": [
#         "Designed and deployed custom YOLOv8 models for computer vision applications.",
#         "Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.",
#         "Worked on Time series data for Adnoc Project.",
#         "Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.",
#         "Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.",
#         "Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment."
#       ]
#     },
#     {
#       "title": "Subject Matter Expert (Data Analyst)",
#       "company": "Tudip Technologies",
#       "dates": "Oct 2020 - Oct 2023",
#       "description": [
#         "Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.",
#         "Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.",
#         "Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.",
#         "Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.",
#         "Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation."
#       ]
#     }
#   ],
#   "skills": {
#     "technical": [
#       "Data Science",
#       "Machine Learning",
#       "Deep Learning",
#       "NLP",
#       "Computer Vision",
#       "LLMs",
#       "LLM Fine Tuning",
#       "Generative AI",
#       "OpenCV",
#       "YOLOv8",
#       "Image Processing",
#       "Object Detection",
#       "GANs",
#       "Signal Processing",
#       "Time Series Analysis",
#       "Tensorflow",
#       "Pytorch",
#       "Keras",
#       "Langchain",
#       "GCP Cloud Run",
#       "Amazon SageMaker",
#       "Numpy",
#       "Pandas",
#       "Scikit-learn",
#       "Spacy",
#       "NLTK",
#       "Matplotlib",
#       "Seaborn",
#       "Scipy",
#       "Jupyter Notebooks",
#       "Docker",
#       "GitHub",
#       "Git",
#       "Google Data Studio",
#       "Statistics & Probability",
#       "Calculus",
#       "Mathematics",
#       "Linear Algebra",
#       "Statistical Analysis",
#       "Data Mining",
#       "Model Building",
#       "Model Deployment",
#       "Hypothesis Testing",
#       "Data Analytics"
#     ],
#     "soft_skills": [
#       "Analytical Thinking",
#       "Problem Solving",
#       "Collaboration",
#       "Communication",
#       "Continuous Learning",
#       "Adaptability",
#       "Time Management"
#     ],
#     "tools_with_levels": [
#       {
#         "tool": "Amazon SageMaker",
#         "level": "basic"
#       }
#     ],
#     "languages": [
#       {
#         "language": "Python",
#         "level": "-"
#       },
#       {
#         "language": "SQL",
#         "level": "-"
#       },
#       {
#         "language": "HTML",
#         "level": "-"
#       },
#       {
#         "language": "CSS",
#         "level": "-"
#       }
#     ]
#   }
# }
# ```
# {'contact_information': {'name': 'Surya Teja Menta',
#   'email': '-',
#   'phone': '+91 8309584461',
#   'linkedin': '-',
#   'jobdb_link': '-',
#   'portfolio_link': 'suryatejamenta.co.in'},
#  'professional_summary': {'has_summary': 'Yes',
#   'summary_points': ['I’m Surya Teja Menta, Results-driven Senior Data Scientist with 4+ years of experience in Data Science, Machine Learning (ML), and Generative AI (GenAI).',
#    'Proven expertise in RAG (Retrieval-Augmented Generation), LLM fine-tuning, MLOps, and end-to-end AI solutions.',
#    'Strong background in data analytics, statistical modeling, AI-powered automation, and scalable AI architectures.',
#    'IBM Certified Professional Data Scientist with hands-on experience in LangChain, Hugging Face, OpenAI APIs, Vector Databases (ChromaDB, Pinecone), and cloud deployments (AWS, GCP).',
#    'Passionate about AI research, model optimization, and developing cutting-edge AI solutions.']},
#  'education': [{'institution': 'PBR VITS, Kavali, AP',
#    'degree': "Bachelor's Degree in Computer Science",
#    'dates': 'June 2016 - May 2020',
#    'gpa': '78.3%',
#    'honors': 'Participated in paper presentations and won prizes.'},
#   {'institution': 'Narayana Junior College, Kavali, AP',
#    'degree': 'HSC',
#    'dates': 'June 2014 - May 2016',
#    'gpa': '92.5%',
#    'honors': '-'},
#   {'institution': 'Kranthi EM School, Kavali, AP',
#    'degree': 'SSC',
#    'dates': 'June 2004 - May 2014',
#    'gpa': '87%',
#    'honors': 'Participated in school dramas, sports, etc.'}],
#  'experience': [{'title': 'Senior Data Scientist',
#    'company': 'Robert Bosch',
#    'dates': 'Jan 2024 - Present',
#    'description': ['Designed and deployed custom YOLOv8 models for computer vision applications.',
#     'Built multi-modal RAG pipelines for intelligent document processing, contextual retrieval, and GenAI-powered insights.',
#     'Worked on Time series data for Adnoc Project.',
#     'Developed ML algorithms for signal processing and sensor vibration data analytics using scikit-learn, PyTorch, and TensorFlow.',
#     'Worked on LLM fine-tuning, prompt engineering, and efficient model inference for enterprise AI applications.',
#     'Integrated MLOps best practices for scalable AI pipelines, model versioning, and automated deployment.']},
#   {'title': 'Subject Matter Expert (Data Analyst)',
#    'company': 'Tudip Technologies',
#    'dates': 'Oct 2020 - Oct 2023',
#    'description': ['Developed interactive analytics dashboards and data reports in Google Data Studio for content management analytics.',
#     'Automated text summarization & paraphrasing using NLP Transformers (BART, T5) and deployed on Google Cloud Run.',
#     'Built AI-powered data visualization tools to enhance real-time business intelligence and trend analysis.',
#     'Integrated LLM-powered chatbots with Google Sheets API to improve data accessibility across teams.',
#     'Recognized with the Best Team Award for highest client appreciation and impactful AI-driven automation.']}],
#  'skills': {'technical': ['Data Science',
#    'Machine Learning',
#    'Deep Learning',
#    'NLP',
#    'Computer Vision',
#    'LLMs',
#    'LLM Fine Tuning',
#    'Generative AI',
#    'OpenCV',
#    'YOLOv8',
#    'Image Processing',
#    'Object Detection',
#    'GANs',
#    'Signal Processing',
#    'Time Series Analysis',
#    'Tensorflow',
#    'Pytorch',
#    'Keras',
#    'Langchain',
#    'GCP Cloud Run',
#    'Amazon SageMaker',
#    'Numpy',
#    'Pandas',
#    'Scikit-learn',
#    'Spacy',
#    'NLTK',
#    'Matplotlib',
#    'Seaborn',
#    'Scipy',
#    'Jupyter Notebooks',
#    'Docker',
#    'GitHub',
#    'Git',
#    'Google Data Studio',
#    'Statistics & Probability',
#    'Calculus',
#    'Mathematics',
#    'Linear Algebra',
#    'Statistical Analysis',
#    'Data Mining',
#    'Model Building',
#    'Model Deployment',
#    'Hypothesis Testing',
#    'Data Analytics'],
#   'soft_skills': ['Analytical Thinking',
#    'Problem Solving',
#    'Collaboration',
#    'Communication',
#    'Continuous Learning',
#    'Adaptability',
#    'Time Management'],
#   'tools_with_levels': [{'tool': 'Amazon SageMaker', 'level': 'basic'}],
#   'languages': [{'language': 'Python', 'level': '-'},
#    {'language': 'SQL', 'level': '-'},
#    {'language': 'HTML', 'level': '-'},
#    {'language': 'CSS', 'level': '-'}]}}

# %%
p4 = PromptBuilder( 
    section  = "Experience", 
    criteria = ["Completeness", "ContentQuality","Grammar","Length","RoleRelevance"],
    cvresume = resume_json
)
prompt4 = p4.build()
# print(prompt4)

# %%
p5 = PromptBuilder( 
    section  = "Activities", 
    criteria = ["Completeness", "ContentQuality","Grammar","Length"],
    cvresume = resume_json
)
prompt5 = p5.build()
# print(prompt5)

# %%
p6 = PromptBuilder( 
    section  = "Skills", 
    criteria = ["Completeness","Length","RoleRelevance"],
    cvresume = resume_json
)
prompt6 = p6.build()
# print(prompt6)

# %% [markdown]
# <hr>

# %% [markdown]
# ### 03 LLMCaller

# %%
import re
import json

# %%
class LlmCaller(helperfunction):
    def __init__(self):
        GOOGLE_API_KEY = self.load_yaml("global.yaml")["setting"]["GOOGLE_API_KEY"]
        self.client    = genai.Client(api_key=GOOGLE_API_KEY)
        self.model     = self.load_yaml("model.yaml")["model"]["generation_model"]
    def parser(self,resp):
        text = resp.text.strip()
        text = re.sub(r"^```json|```$", "", text).strip()
        data = json.loads(text)
        return data
    def hit(self,prompt):
        self.prompt = prompt
        self.resp = self.client.models.generate_content(
            model    = self.model,
            contents = self.prompt
            )
        data = self.parser(self.resp)
        return data

# %%
op = LlmCaller()

# %%
op1 = op.hit(prompt1)
op2 = op.hit(prompt2)
op3 = op.hit(prompt3)
op4 = op.hit(prompt4)
op5 = op.hit(prompt5)
op6 = op.hit(prompt6)

# %%
op1
# Out:
# {'section': 'Profile',
#  'scores': {'ContentQuality': {'score': 5,
#    'feedback': "The professional summary (acting as the Profile section) is exceptionally high quality. It clearly articulates the candidate's core competencies, relevant experience (4+ years), and specialized skills in cutting-edge AI technologies (GenAI, RAG, LLM fine-tuning, MLOps). The inclusion of certifications (IBM Certified Professional Data Scientist) and specific tools/platforms (LangChain, Hugging Face, AWS, GCP) adds significant value and credibility. The language is professional, confident, and highly impactful, making a strong case for the candidate's expertise."},
#   'Completeness': {'score': 5,
#    'feedback': "This section is complete and fully meets all expected criteria. It clearly establishes the candidate's basic professional identity ('Surya Teja Menta, Results-driven Senior Data Scientist'), provides clear positioning with specific domains (Data Science, Machine Learning, Generative AI), and outlines a strong career direction. It effectively highlights key skills and certifications upfront. There are no unnecessary personal details, maintaining a professional and concise profile."}}}

# %%
op2
# Out:
# {'section': 'Summary',
#  'scores': {'RoleRelevance': {'score': 5,
#    'feedback': 'The summary is perfectly aligned with a Senior Data Scientist role, heavily emphasizing relevant experience (4+ years), key technologies (RAG, LLM fine-tuning, MLOps, GenAI), specific tools (LangChain, Hugging Face, Vector Databases, AWS, GCP), and a pertinent career focus.'},
#   'Length': {'score': 2,
#    'feedback': 'The summary consists of 5 sentences, which slightly exceeds the recommended 2-4 sentence length for a concise summary. While each point is strong, combining some ideas could enhance conciseness.'},
#   'Grammar': {'score': 5,
#    'feedback': 'The summary is impeccably written with no grammatical errors, spelling mistakes, or punctuation issues. It demonstrates strong written communication skills.'},
#   'ContentQuality': {'score': 4,
#    'feedback': "The content is strong, specific, and impactful. It highlights concrete expertise (RAG, LLM fine-tuning), specific tools, a relevant certification, and a clear value proposition. While it uses 'Results-driven' and 'cutting-edge,' the overall specificity of technologies and domains listed prevents it from being overly buzzword-heavy and adds significant value."},
#   'Completeness': {'score': 5,
#    'feedback': 'The summary comprehensively covers all expected elements: it provides a concise summary of experience (4+ years, Senior Data Scientist), clearly articulates technical and domain strengths (GenAI, ML, RAG, LLM, MLOps, data analytics), highlights specific tools and certifications, and effectively communicates career focus and value proposition (AI research, model optimization, cutting-edge solutions).'}}}

# %%
op3
# Out:
# {'section': 'Education',
#  'scores': {'RoleRelevance': {'score': 4,
#    'feedback': "The Bachelor's Degree in Computer Science is highly relevant and provides a strong foundation for a data career, especially for a Senior Data Scientist role. The mention of participation in paper presentations further suggests relevant academic engagement. However, the inclusion of HSC and SSC details, while complete, adds minimal direct relevance for a candidate with 4+ years of experience targeting a senior professional role."},
#   'Completeness': {'score': 5,
#    'feedback': 'All expected components (institution, degree, dates, GPA/percentage, and honors where applicable) are clearly listed for each educational entry. The inclusion of academic performance and relevant extracurriculars/achievements (paper presentations) is excellent.'}}}

# %%
print(op3)
# Out:
# {'section': 'Education', 'scores': {'RoleRelevance': {'score': 4, 'feedback': "The Bachelor's Degree in Computer Science is highly relevant and provides a strong foundation for a data career, especially for a Senior Data Scientist role. The mention of participation in paper presentations further suggests relevant academic engagement. However, the inclusion of HSC and SSC details, while complete, adds minimal direct relevance for a candidate with 4+ years of experience targeting a senior professional role."}, 'Completeness': {'score': 5, 'feedback': 'All expected components (institution, degree, dates, GPA/percentage, and honors where applicable) are clearly listed for each educational entry. The inclusion of academic performance and relevant extracurriculars/achievements (paper presentations) is excellent.'}}}

# %%
op4
# Out:
# {'section': 'Experience',
#  'scores': {'RoleRelevance': {'score': 5,
#    'feedback': 'The experience section clearly demonstrates a strong alignment with Data Scientist and Data Analyst roles, showcasing relevant responsibilities, tools, and methodologies pertinent to the field.'},
#   'Length': {'score': 5,
#    'feedback': 'The length of the experience section is appropriate and well-balanced. Each role has a concise yet informative number of bullet points, making it easy to read and digest without being overly verbose.'},
#   'Grammar': {'score': 5,
#    'feedback': 'The grammar, spelling, and punctuation throughout the experience section are excellent. The bullet points are clear, professional, and free of errors.'},
#   'ContentQuality': {'score': 3,
#    'feedback': "The content quality is sufficient but could be stronger. Many bullet points effectively use an 'Action → method' structure and list relevant technical tools (e.g., YOLOv8, scikit-learn, PyTorch, Google Data Studio, NLP Transformers). However, there's a significant lack of quantifiable metrics to demonstrate impact or scale. While some points hint at impact (e.g., 'enhance real-time business intelligence', 'improve data accessibility'), concrete numbers, percentages, or specific results are missing. Some bullet points are also a bit weak ('Worked on Time series data for Adnoc Project.')."},
#   'Completeness': {'score': 5,
#    'feedback': 'The experience section is complete. It clearly lists the job title, employer, and dates for each position. The use of clear bullet points for descriptions is also well-executed.'}}}

# %%
op5
# Out:
# {'section': 'Activities',
#  'scores': {'Length': {'score': 0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for length."},
#   'Grammar': {'score': 0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for grammar."},
#   'ContentQuality': {'score': 0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content (competitions, hackathons, club activities, or non-work projects) to evaluate for quality."},
#   'Completeness': {'score': 0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. None of the expected content (competitions, hackathons, club activities, project descriptions, or tools/tech) is present in a dedicated section."}}}

# %%
op6
# Out:
# {'section': 'Skills',
#  'scores': {'RoleRelevance': {'score': 5,
#    'feedback': 'The skills section demonstrates exceptional relevance to a Senior Data Scientist role. It covers a vast array of cutting-edge technologies and methodologies in Data Science, Machine Learning, Deep Learning, NLP, Computer Vision, LLMs, GenAI, and MLOps, directly aligning with the professional summary and experience. The inclusion of frameworks like TensorFlow, PyTorch, Keras, LangChain, cloud platforms (GCP, AWS SageMaker), and statistical foundations makes it highly pertinent and future-proof.'},
#   'Length': {'score': 4,
#    'feedback': "The length is robust and comprehensive, particularly in the technical skills section, which is appropriate for a Senior Data Scientist showcasing broad expertise. While extensive, it effectively conveys the candidate's capabilities without feeling overly verbose or containing irrelevant entries. It's detailed enough to impress without being excessive, though a slight consolidation or more explicit grouping of tools could refine it further."},
#   'Completeness': {'score': 3,
#    'feedback': "The section covers all expected categories: technical skills, soft skills, and languages, with clear grouping. However, there are areas for improvement regarding completeness of detail. Language proficiency levels are missing for Python, SQL, HTML, and CSS, which are crucial for assessing capability. The 'tools_with_levels' category is largely underutilized, with many tools listed generically under 'technical' without specific proficiency indicators. While a wide range of relevant skills is present, the lack of depth in proficiency levels and inconsistent tool categorization reduces the overall completeness of information."}}}

# %% [markdown]
# <hr>

# %% [markdown]
# ### 04 SectionScoreAggregator

# %%
import copy
class SectionScoreAggregator(helperfunction):
    def __init__(self):
        self.config          = self.load_yaml("weight.yaml")         # config
    def aggregate(self,llm_output:dict):
        self.llm_output      = llm_output             # op
        self.section         = llm_output["section"]  # Get section
        self.section_weights = self.config["weights"][self.section]  # config["weights"][section_key][criteria]
        ddict = {}
        total = 0.0
        # Protect multiple mutation when we run more than one time
        scores_copy = copy.deepcopy(self.llm_output["scores"])
        for criteria, body in scores_copy.items():
            raw = body["score"]
            w   = self.section_weights[criteria]
            weighted = raw / 5 * w
            body["score"] = weighted
            ddict[criteria] = body
            total = total + weighted
        return {
            "section": self.section,
            "total_score":total,
            "scores":ddict
        }

# %%
agg = SectionScoreAggregator()

# %%
s1 = agg.aggregate(op1)
s1
# Out:
# {'section': 'Profile',
#  'total_score': 20.0,
#  'scores': {'ContentQuality': {'score': 10.0,
#    'feedback': "The professional summary (acting as the Profile section) is exceptionally high quality. It clearly articulates the candidate's core competencies, relevant experience (4+ years), and specialized skills in cutting-edge AI technologies (GenAI, RAG, LLM fine-tuning, MLOps). The inclusion of certifications (IBM Certified Professional Data Scientist) and specific tools/platforms (LangChain, Hugging Face, AWS, GCP) adds significant value and credibility. The language is professional, confident, and highly impactful, making a strong case for the candidate's expertise."},
#   'Completeness': {'score': 10.0,
#    'feedback': "This section is complete and fully meets all expected criteria. It clearly establishes the candidate's basic professional identity ('Surya Teja Menta, Results-driven Senior Data Scientist'), provides clear positioning with specific domains (Data Science, Machine Learning, Generative AI), and outlines a strong career direction. It effectively highlights key skills and certifications upfront. There are no unnecessary personal details, maintaining a professional and concise profile."}}}

# %%
s2 = agg.aggregate(op2)
s2
# Out:
# {'section': 'Summary',
#  'total_score': 42.0,
#  'scores': {'RoleRelevance': {'score': 10.0,
#    'feedback': 'The summary is perfectly aligned with a Senior Data Scientist role, heavily emphasizing relevant experience (4+ years), key technologies (RAG, LLM fine-tuning, MLOps, GenAI), specific tools (LangChain, Hugging Face, Vector Databases, AWS, GCP), and a pertinent career focus.'},
#   'Length': {'score': 4.0,
#    'feedback': 'The summary consists of 5 sentences, which slightly exceeds the recommended 2-4 sentence length for a concise summary. While each point is strong, combining some ideas could enhance conciseness.'},
#   'Grammar': {'score': 10.0,
#    'feedback': 'The summary is impeccably written with no grammatical errors, spelling mistakes, or punctuation issues. It demonstrates strong written communication skills.'},
#   'ContentQuality': {'score': 8.0,
#    'feedback': "The content is strong, specific, and impactful. It highlights concrete expertise (RAG, LLM fine-tuning), specific tools, a relevant certification, and a clear value proposition. While it uses 'Results-driven' and 'cutting-edge,' the overall specificity of technologies and domains listed prevents it from being overly buzzword-heavy and adds significant value."},
#   'Completeness': {'score': 10.0,
#    'feedback': 'The summary comprehensively covers all expected elements: it provides a concise summary of experience (4+ years, Senior Data Scientist), clearly articulates technical and domain strengths (GenAI, ML, RAG, LLM, MLOps, data analytics), highlights specific tools and certifications, and effectively communicates career focus and value proposition (AI research, model optimization, cutting-edge solutions).'}}}

# %%
s3 = agg.aggregate(op3)
s3
# Out:
# {'section': 'Education',
#  'total_score': 18.0,
#  'scores': {'RoleRelevance': {'score': 8.0,
#    'feedback': "The Bachelor's Degree in Computer Science is highly relevant and provides a strong foundation for a data career, especially for a Senior Data Scientist role. The mention of participation in paper presentations further suggests relevant academic engagement. However, the inclusion of HSC and SSC details, while complete, adds minimal direct relevance for a candidate with 4+ years of experience targeting a senior professional role."},
#   'Completeness': {'score': 10.0,
#    'feedback': 'All expected components (institution, degree, dates, GPA/percentage, and honors where applicable) are clearly listed for each educational entry. The inclusion of academic performance and relevant extracurriculars/achievements (paper presentations) is excellent.'}}}

# %%
s4 = agg.aggregate(op4)
s4
# Out:
# {'section': 'Experience',
#  'total_score': 46.0,
#  'scores': {'RoleRelevance': {'score': 10.0,
#    'feedback': 'The experience section clearly demonstrates a strong alignment with Data Scientist and Data Analyst roles, showcasing relevant responsibilities, tools, and methodologies pertinent to the field.'},
#   'Length': {'score': 10.0,
#    'feedback': 'The length of the experience section is appropriate and well-balanced. Each role has a concise yet informative number of bullet points, making it easy to read and digest without being overly verbose.'},
#   'Grammar': {'score': 10.0,
#    'feedback': 'The grammar, spelling, and punctuation throughout the experience section are excellent. The bullet points are clear, professional, and free of errors.'},
#   'ContentQuality': {'score': 6.0,
#    'feedback': "The content quality is sufficient but could be stronger. Many bullet points effectively use an 'Action → method' structure and list relevant technical tools (e.g., YOLOv8, scikit-learn, PyTorch, Google Data Studio, NLP Transformers). However, there's a significant lack of quantifiable metrics to demonstrate impact or scale. While some points hint at impact (e.g., 'enhance real-time business intelligence', 'improve data accessibility'), concrete numbers, percentages, or specific results are missing. Some bullet points are also a bit weak ('Worked on Time series data for Adnoc Project.')."},
#   'Completeness': {'score': 10.0,
#    'feedback': 'The experience section is complete. It clearly lists the job title, employer, and dates for each position. The use of clear bullet points for descriptions is also well-executed.'}}}

# %%
s5 = agg.aggregate(op5)
s5
# Out:
# {'section': 'Activities',
#  'total_score': 0.0,
#  'scores': {'Length': {'score': 0.0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for length."},
#   'Grammar': {'score': 0.0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for grammar."},
#   'ContentQuality': {'score': 0.0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. There is no content (competitions, hackathons, club activities, or non-work projects) to evaluate for quality."},
#   'Completeness': {'score': 0.0,
#    'feedback': "The 'Activities' section is entirely missing from the resume. None of the expected content (competitions, hackathons, club activities, project descriptions, or tools/tech) is present in a dedicated section."}}}

# %%
s6 = agg.aggregate(op6)
s6
# Out:
# {'section': 'Skills',
#  'total_score': 24.0,
#  'scores': {'RoleRelevance': {'score': 10.0,
#    'feedback': 'The skills section demonstrates exceptional relevance to a Senior Data Scientist role. It covers a vast array of cutting-edge technologies and methodologies in Data Science, Machine Learning, Deep Learning, NLP, Computer Vision, LLMs, GenAI, and MLOps, directly aligning with the professional summary and experience. The inclusion of frameworks like TensorFlow, PyTorch, Keras, LangChain, cloud platforms (GCP, AWS SageMaker), and statistical foundations makes it highly pertinent and future-proof.'},
#   'Length': {'score': 8.0,
#    'feedback': "The length is robust and comprehensive, particularly in the technical skills section, which is appropriate for a Senior Data Scientist showcasing broad expertise. While extensive, it effectively conveys the candidate's capabilities without feeling overly verbose or containing irrelevant entries. It's detailed enough to impress without being excessive, though a slight consolidation or more explicit grouping of tools could refine it further."},
#   'Completeness': {'score': 6.0,
#    'feedback': "The section covers all expected categories: technical skills, soft skills, and languages, with clear grouping. However, there are areas for improvement regarding completeness of detail. Language proficiency levels are missing for Python, SQL, HTML, and CSS, which are crucial for assessing capability. The 'tools_with_levels' category is largely underutilized, with many tools listed generically under 'technical' without specific proficiency indicators. While a wide range of relevant skills is present, the lack of depth in proficiency levels and inconsistent tool categorization reduces the overall completeness of information."}}}

# %%
print(x.jsonstr(op3))
# Out:
# {
#     "section": "Education",
#     "scores": {
#         "RoleRelevance": {
#             "score": 4,
#             "feedback": "The Bachelor's Degree in Computer Science is highly relevant and provides a strong foundation for a data career, especially for a Senior Data Scientist role. The mention of participation in paper presentations further suggests relevant academic engagement. However, the inclusion of HSC and SSC details, while complete, adds minimal direct relevance for a candidate with 4+ years of experience targeting a senior professional role."
#         },
#         "Completeness": {
#             "score": 5,
#             "feedback": "All expected components (institution, degree, dates, GPA/percentage, and honors where applicable) are clearly listed for each educational entry. The inclusion of academic performance and relevant extracurriculars/achievements (paper presentations) is excellent."
#         }
#     }
# }

# %% [markdown]
# <hr>

# %% [markdown]
# ### 05 GlobalAggregator

# %%
from datetime import datetime,timezone,timedelta

# %%
class GlobalAggregator(helperfunction):
    def __init__(self,SectionScoreAggregator_output:list):
        self.section_outputs = SectionScoreAggregator_output
        self.timestamp       = str(datetime.now(tz=(timezone(timedelta(hours=7)))))
        self.model_config    = self.load_yaml("model.yaml")     # should include model name
        self.weight_config   = self.load_yaml("weight.yaml")    # includes weights + version
        self.prompt_config   = self.load_yaml("prompt.yaml")    # includes prompt version
    def fn1(self):
        weights = self.weight_config["weights"]
        contribution = {}
        total = 0.0
        for section_data in self.section_outputs:
            section_name    = section_data["section"]
            total_score     = section_data["total_score"]
            section_weight  = weights[section_name]["section_weight"]
            section_contrib = total_score * section_weight
            contribution[section_name] = {
                "section_total": total_score,
                "section_weight": section_weight,
                "contribution": self.fop(section_contrib)
            }
            total = total + section_contrib
        return {
            "final_resume_score":self.fop(total),
            "section_contribution":contribution
        }
    def fn2(self):
        details = {}
        for section_data in self.section_outputs:
            details[section_data["section"]] = {
                'total_score':section_data['total_score'],
                'scores':section_data['scores']
            }
        return details
    def fn3(self):
        return {
            "model_name": self.model_config['model']['generation_model'],
            "timestamp": self.timestamp,
            "weights_version": self.weight_config.get("version", "unknown"),
            "prompt_version": self.prompt_config.get("version", "unknown")
        }
    def fn0(self):
        conclution_part = self.fn1()
        detail_part     = self.fn2()
        metadata_part   = self.fn3()
        # return {
        #     "conclution":conclution_part,
        #     "section_detail":detail_part,
        #     "metadata":metadata_part
        # }
        return self.jsonstr({
            "conclution":conclution_part,
            "section_detail":detail_part,
            "metadata":metadata_part
        })

# %%
x = GlobalAggregator(
    SectionScoreAggregator_output = [s1,s2,s3,s4,s5,s6]
)

# %%
output = x.fn0()
print(output)
# Out:
# {
#     "conclution": {
#         "final_resume_score": 23.8,
#         "section_contribution": {
#             "Profile": {
#                 "section_total": 20.0,
#                 "section_weight": 0.1,
#                 "contribution": 2.0
#             },
#             "Summary": {
#                 "section_total": 42.0,
#                 "section_weight": 0.1,
#                 "contribution": 4.2
#             },
#             "Education": {
#                 "section_total": 18.0,
#                 "section_weight": 0.2,
#                 "contribution": 3.6
#             },
#             "Experience": {
#                 "section_total": 46.0,
#                 "section_weight": 0.2,
#                 "contribution": 9.2
#             },
#             "Activities": {
#                 "section_total": 0.0,
#                 "section_weight": 0.2,
#                 "contribution": 0.0
#             },
#             "Skills": {
#                 "section_total": 24.0,
#                 "section_weight": 0.2,
#                 "contribution": 4.8
#             }
#         }
#     },
#     "section_detail": {
#         "Profile": {
#             "total_score": 20.0,
#             "scores": {
#                 "ContentQuality": {
#                     "score": 10.0,
#                     "feedback": "The professional summary (acting as the Profile section) is exceptionally high quality. It clearly articulates the candidate's core competencies, relevant experience (4+ years), and specialized skills in cutting-edge AI technologies (GenAI, RAG, LLM fine-tuning, MLOps). The inclusion of certifications (IBM Certified Professional Data Scientist) and specific tools/platforms (LangChain, Hugging Face, AWS, GCP) adds significant value and credibility. The language is professional, confident, and highly impactful, making a strong case for the candidate's expertise."
#                 },
#                 "Completeness": {
#                     "score": 10.0,
#                     "feedback": "This section is complete and fully meets all expected criteria. It clearly establishes the candidate's basic professional identity ('Surya Teja Menta, Results-driven Senior Data Scientist'), provides clear positioning with specific domains (Data Science, Machine Learning, Generative AI), and outlines a strong career direction. It effectively highlights key skills and certifications upfront. There are no unnecessary personal details, maintaining a professional and concise profile."
#                 }
#             }
#         },
#         "Summary": {
#             "total_score": 42.0,
#             "scores": {
#                 "RoleRelevance": {
#                     "score": 10.0,
#                     "feedback": "The summary is perfectly aligned with a Senior Data Scientist role, heavily emphasizing relevant experience (4+ years), key technologies (RAG, LLM fine-tuning, MLOps, GenAI), specific tools (LangChain, Hugging Face, Vector Databases, AWS, GCP), and a pertinent career focus."
#                 },
#                 "Length": {
#                     "score": 4.0,
#                     "feedback": "The summary consists of 5 sentences, which slightly exceeds the recommended 2-4 sentence length for a concise summary. While each point is strong, combining some ideas could enhance conciseness."
#                 },
#                 "Grammar": {
#                     "score": 10.0,
#                     "feedback": "The summary is impeccably written with no grammatical errors, spelling mistakes, or punctuation issues. It demonstrates strong written communication skills."
#                 },
#                 "ContentQuality": {
#                     "score": 8.0,
#                     "feedback": "The content is strong, specific, and impactful. It highlights concrete expertise (RAG, LLM fine-tuning), specific tools, a relevant certification, and a clear value proposition. While it uses 'Results-driven' and 'cutting-edge,' the overall specificity of technologies and domains listed prevents it from being overly buzzword-heavy and adds significant value."
#                 },
#                 "Completeness": {
#                     "score": 10.0,
#                     "feedback": "The summary comprehensively covers all expected elements: it provides a concise summary of experience (4+ years, Senior Data Scientist), clearly articulates technical and domain strengths (GenAI, ML, RAG, LLM, MLOps, data analytics), highlights specific tools and certifications, and effectively communicates career focus and value proposition (AI research, model optimization, cutting-edge solutions)."
#                 }
#             }
#         },
#         "Education": {
#             "total_score": 18.0,
#             "scores": {
#                 "RoleRelevance": {
#                     "score": 8.0,
#                     "feedback": "The Bachelor's Degree in Computer Science is highly relevant and provides a strong foundation for a data career, especially for a Senior Data Scientist role. The mention of participation in paper presentations further suggests relevant academic engagement. However, the inclusion of HSC and SSC details, while complete, adds minimal direct relevance for a candidate with 4+ years of experience targeting a senior professional role."
#                 },
#                 "Completeness": {
#                     "score": 10.0,
#                     "feedback": "All expected components (institution, degree, dates, GPA/percentage, and honors where applicable) are clearly listed for each educational entry. The inclusion of academic performance and relevant extracurriculars/achievements (paper presentations) is excellent."
#                 }
#             }
#         },
#         "Experience": {
#             "total_score": 46.0,
#             "scores": {
#                 "RoleRelevance": {
#                     "score": 10.0,
#                     "feedback": "The experience section clearly demonstrates a strong alignment with Data Scientist and Data Analyst roles, showcasing relevant responsibilities, tools, and methodologies pertinent to the field."
#                 },
#                 "Length": {
#                     "score": 10.0,
#                     "feedback": "The length of the experience section is appropriate and well-balanced. Each role has a concise yet informative number of bullet points, making it easy to read and digest without being overly verbose."
#                 },
#                 "Grammar": {
#                     "score": 10.0,
#                     "feedback": "The grammar, spelling, and punctuation throughout the experience section are excellent. The bullet points are clear, professional, and free of errors."
#                 },
#                 "ContentQuality": {
#                     "score": 6.0,
#                     "feedback": "The content quality is sufficient but could be stronger. Many bullet points effectively use an 'Action → method' structure and list relevant technical tools (e.g., YOLOv8, scikit-learn, PyTorch, Google Data Studio, NLP Transformers). However, there's a significant lack of quantifiable metrics to demonstrate impact or scale. While some points hint at impact (e.g., 'enhance real-time business intelligence', 'improve data accessibility'), concrete numbers, percentages, or specific results are missing. Some bullet points are also a bit weak ('Worked on Time series data for Adnoc Project.')."
#                 },
#                 "Completeness": {
#                     "score": 10.0,
#                     "feedback": "The experience section is complete. It clearly lists the job title, employer, and dates for each position. The use of clear bullet points for descriptions is also well-executed."
#                 }
#             }
#         },
#         "Activities": {
#             "total_score": 0.0,
#             "scores": {
#                 "Length": {
#                     "score": 0.0,
#                     "feedback": "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for length."
#                 },
#                 "Grammar": {
#                     "score": 0.0,
#                     "feedback": "The 'Activities' section is entirely missing from the resume. There is no content to evaluate for grammar."
#                 },
#                 "ContentQuality": {
#                     "score": 0.0,
#                     "feedback": "The 'Activities' section is entirely missing from the resume. There is no content (competitions, hackathons, club activities, or non-work projects) to evaluate for quality."
#                 },
#                 "Completeness": {
#                     "score": 0.0,
#                     "feedback": "The 'Activities' section is entirely missing from the resume. None of the expected content (competitions, hackathons, club activities, project descriptions, or tools/tech) is present in a dedicated section."
#                 }
#             }
#         },
#         "Skills": {
#             "total_score": 24.0,
#             "scores": {
#                 "RoleRelevance": {
#                     "score": 10.0,
#                     "feedback": "The skills section demonstrates exceptional relevance to a Senior Data Scientist role. It covers a vast array of cutting-edge technologies and methodologies in Data Science, Machine Learning, Deep Learning, NLP, Computer Vision, LLMs, GenAI, and MLOps, directly aligning with the professional summary and experience. The inclusion of frameworks like TensorFlow, PyTorch, Keras, LangChain, cloud platforms (GCP, AWS SageMaker), and statistical foundations makes it highly pertinent and future-proof."
#                 },
#                 "Length": {
#                     "score": 8.0,
#                     "feedback": "The length is robust and comprehensive, particularly in the technical skills section, which is appropriate for a Senior Data Scientist showcasing broad expertise. While extensive, it effectively conveys the candidate's capabilities without feeling overly verbose or containing irrelevant entries. It's detailed enough to impress without being excessive, though a slight consolidation or more explicit grouping of tools could refine it further."
#                 },
#                 "Completeness": {
#                     "score": 6.0,
#                     "feedback": "The section covers all expected categories: technical skills, soft skills, and languages, with clear grouping. However, there are areas for improvement regarding completeness of detail. Language proficiency levels are missing for Python, SQL, HTML, and CSS, which are crucial for assessing capability. The 'tools_with_levels' category is largely underutilized, with many tools listed generically under 'technical' without specific proficiency indicators. While a wide range of relevant skills is present, the lack of depth in proficiency levels and inconsistent tool categorization reduces the overall completeness of information."
#                 }
#             }
#         }
#     },
#     "metadata": {
#         "model_name": "gemini-2.5-flash",
#         "timestamp": "2025-12-04 13:35:18.485266+07:00",
#         "weights_version": "weights_v1",
#         "prompt_version": "prompt_v1"
#     }
# }

# %% [markdown]
# <hr>
